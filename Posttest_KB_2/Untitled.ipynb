# %% [markdown]
# # Maezar Abdillah
# ## 2109106029
# ### Postes 1 Kecerdasan Buatan

# %% [markdown]
# #### Mengimport library pandas

# %%
import pandas as pd

# %%
df = pd.read_csv("covid_19_indonesia_time_series_all.csv")
df.head(10)
# Out:
#        Date Location ISO Code     Location  New Cases  New Deaths  \
# 0  3/1/2020             ID-JK  DKI Jakarta          2           0
# 1  3/2/2020             ID-JK  DKI Jakarta          2           0
# 2  3/2/2020               IDN    Indonesia          2           0
# 3  3/2/2020             ID-RI         Riau          1           0
# 4  3/3/2020             ID-JK  DKI Jakarta          2           0
# 5  3/3/2020               IDN    Indonesia          0           0
# 6  3/3/2020             ID-JB   Jawa Barat          1           1
# 7  3/3/2020             ID-RI         Riau          0           0
# 8  3/4/2020             ID-JK  DKI Jakarta          2           0
# 9  3/4/2020               IDN    Indonesia          0           0
#
#    New Recovered  New Active Cases  Total Cases  Total Deaths  \
# 0              0                 2           39            20
# 1              0                 2           41            20
# ...

# %%
df.tail(5)
# Out:
#             Date Location ISO Code          Location  New Cases  New Deaths  \
# 31817  9/15/2022             ID-SA    Sulawesi Utara         37           0
# 31818  9/15/2022             ID-SB    Sumatera Barat         13           0
# 31819  9/15/2022             ID-SS  Sumatera Selatan         16           0
# 31820  9/15/2022             ID-SU    Sumatera Utara         50           0
# 31821  9/16/2022               IDN         Indonesia       2358          27
#
#        New Recovered  New Active Cases  Total Cases  Total Deaths  \
# 31817              0                37        52770          1213
# 31818              3                10       104640          2371
# 31819              1                15        82198          3376
# 31820              5                45       158866          3288
# 31821           2997              -666      6405044        157876
#
#        Total Recovered  ...  Latitude New Cases per Million  \
# ...

# %% [markdown]
# #### Melihat informasi tipe data masing masing attribute

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31822 entries, 0 to 31821
# Data columns (total 38 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Date                         31822 non-null  object
#  1   Location ISO Code            31822 non-null  object
#  2   Location                     31822 non-null  object
#  3   New Cases                    31822 non-null  int64
#  4   New Deaths                   31822 non-null  int64
#  5   New Recovered                31822 non-null  int64
#  6   New Active Cases             31822 non-null  int64
#  7   Total Cases                  31822 non-null  int64
#  8   Total Deaths                 31822 non-null  int64
#  9   Total Recovered              31822 non-null  int64
#  10  Total Active Cases           31822 non-null  int64
#  11  Location Level               31822 non-null  object
#  12  City or Regency              0 non-null      float64
# ...

# %% [markdown]
# #### Mengimport library numpy

# %%
import numpy as np

# %% [markdown]
# #### Menampilkan nilai rata-rata dari salah satu atribut bertipe data angka dari dataset diatas

# %%
df["New Deaths"].mean()
# Out:
# 9.920652378857394

# %% [markdown]
# #### Menampilkan nilai minimum dari salah satu atribut bertipe data angka

# %%
df["New Deaths"].min()
# Out:
# 0

# %% [markdown]
# #### Menampilkan nilai maksimum dari salah satu atribut bertipe data angka

# %%
df["New Deaths"].max()
# Out:
# 2069

# %% [markdown]
# #### Menampilkan nilai Q1,Q2,dan Q3 dari salah satu atribut bertipe data angka

# %%
df["New Deaths"].quantile(0.25)
# Out:
# 0.0

# %%
df["New Deaths"].quantile(0.50)
# Out:
# 0.0

# %%
df["New Deaths"].quantile(0.75)
# Out:
# 3.0

# %% [markdown]
# #### Atau kita juga bisa menggunakan command describe

# %%
df.describe()
# Out:
#           New Cases    New Deaths  New Recovered  New Active Cases  \
# count  31822.000000  31822.000000   31822.000000      31822.000000
# mean     402.311388      9.920652     390.398498          1.992238
# std     2320.629838     64.139080    2199.878802       1219.513355
# min        0.000000      0.000000       0.000000     -29938.000000
# 25%        3.000000      0.000000       2.000000        -12.000000
# 50%       27.000000      0.000000      20.000000          0.000000
# 75%      130.000000      3.000000     123.000000         19.000000
# max    64718.000000   2069.000000   61361.000000      39165.000000
#
#         Total Cases   Total Deaths  Total Recovered  Total Active Cases  \
# count  3.182200e+04   31822.000000     3.182200e+04        31822.000000
# mean   1.594500e+05    4564.753221     1.492615e+05         5623.782415
# std    6.264435e+05   17693.731369     5.958536e+05        28537.412305
# min    1.000000e+00       0.000000     0.000000e+00        -2343.000000
# ...

# %% [markdown]
# #### Merubah nilai salah satu atribut dari desimal ke bilangan bulat

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31822 entries, 0 to 31821
# Data columns (total 38 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Date                         31822 non-null  object
#  1   Location ISO Code            31822 non-null  object
#  2   Location                     31822 non-null  object
#  3   New Cases                    31822 non-null  int64
#  4   New Deaths                   31822 non-null  int64
#  5   New Recovered                31822 non-null  int64
#  6   New Active Cases             31822 non-null  int64
#  7   Total Cases                  31822 non-null  int64
#  8   Total Deaths                 31822 non-null  int64
#  9   Total Recovered              31822 non-null  int64
#  10  Total Active Cases           31822 non-null  int64
#  11  Location Level               31822 non-null  object
#  12  City or Regency              0 non-null      float64
# ...

# %%
df["Longitude"]= df["Longitude"].astype("int64")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31822 entries, 0 to 31821
# Data columns (total 38 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Date                         31822 non-null  object
#  1   Location ISO Code            31822 non-null  object
#  2   Location                     31822 non-null  object
#  3   New Cases                    31822 non-null  int64
#  4   New Deaths                   31822 non-null  int64
#  5   New Recovered                31822 non-null  int64
#  6   New Active Cases             31822 non-null  int64
#  7   Total Cases                  31822 non-null  int64
#  8   Total Deaths                 31822 non-null  int64
#  9   Total Recovered              31822 non-null  int64
#  10  Total Active Cases           31822 non-null  int64
#  11  Location Level               31822 non-null  object
#  12  City or Regency              0 non-null      float64
# ...

# %%
Longitude=df["Longitude"]
Longitude.head(5)
# Out:
# 0    106
# 1    106
# 2    113
# 3    101
# 4    106
# Name: Longitude, dtype: int64

# %% [markdown]
# #### Menampilkan 10 record pertama Atribut bertipe data angka

# %%
df.select_dtypes(include=np.number).head(10)
# Out:
#    New Cases  New Deaths  New Recovered  New Active Cases  Total Cases  \
# 0          2           0              0                 2           39
# 1          2           0              0                 2           41
# 2          2           0              0                 2            2
# 3          1           0              0                 1            1
# 4          2           0              0                 2           43
# 5          0           0              0                 0            2
# 6          1           1              0                 0            1
# 7          0           0              0                 0            1
# 8          2           0              0                 2           45
# 9          0           0              0                 0            2
#
#    Total Deaths  Total Recovered  Total Active Cases  City or Regency  \
# 0            20               75                 -56              NaN
# ...

# %%
df.select_dtypes(include=np.number).to_csv("angka_covid_indonesia.csv")

# %%
df = pd.read_csv("angka_covid_indonesia.csv")
df.head(10)
# Out:
#    Unnamed: 0  New Cases  New Deaths  New Recovered  New Active Cases  \
# 0           0          2           0              0                 2
# 1           1          2           0              0                 2
# 2           2          2           0              0                 2
# 3           3          1           0              0                 1
# 4           4          2           0              0                 2
# 5           5          0           0              0                 0
# 6           6          1           1              0                 0
# 7           7          0           0              0                 0
# 8           8          2           0              0                 2
# 9           9          0           0              0                 0
#
#    Total Cases  Total Deaths  Total Recovered  Total Active Cases  \
# 0           39            20               75                 -56
# ...

# %%
df = pd.read_csv("covid_19_indonesia_time_series_all.csv")
df.head(10)
# Out:
#        Date Location ISO Code     Location  New Cases  New Deaths  \
# 0  3/1/2020             ID-JK  DKI Jakarta          2           0
# 1  3/2/2020             ID-JK  DKI Jakarta          2           0
# 2  3/2/2020               IDN    Indonesia          2           0
# 3  3/2/2020             ID-RI         Riau          1           0
# 4  3/3/2020             ID-JK  DKI Jakarta          2           0
# 5  3/3/2020               IDN    Indonesia          0           0
# 6  3/3/2020             ID-JB   Jawa Barat          1           1
# 7  3/3/2020             ID-RI         Riau          0           0
# 8  3/4/2020             ID-JK  DKI Jakarta          2           0
# 9  3/4/2020               IDN    Indonesia          0           0
#
#    New Recovered  New Active Cases  Total Cases  Total Deaths  \
# 0              0                 2           39            20
# 1              0                 2           41            20
# ...

# %% [markdown]
# #### Informasi yang didapat dari Covid 19 Indonesia Datasets

# %%
info ={
    'total_record':0,
    'atribut': [] ,
    'atribut_object':0,
    'atribut_number':0,
    'null_atribut':0
}

info['total_record'] = df.shape[0]
info['atribut'] = list(df.columns.values)
info['atribut_object'] = list(df.select_dtypes(['object']).columns)
info['atribut_number'] = list(df.select_dtypes(['float64','int64']).columns)
info['null_atribut'] = list(df.loc[:, df.isnull().any()].columns)

# %% [markdown]
# #### Jumlah Record

# %%
print("Jumlah Record : ", info['total_record'])
# Out:
# Jumlah Record :  31822

# %% [markdown]
# #### Nama Atribut dan Jumlah Atribut

# %%
print("Nama-nama Atribut : ", info['atribut'])
print("Jumlah Atribut : ", len(info['atribut']))
# Out:
# Nama-nama Atribut :  ['Date', 'Location ISO Code', 'Location', 'New Cases', 'New Deaths', 'New Recovered', 'New Active Cases', 'Total Cases', 'Total Deaths', 'Total Recovered', 'Total Active Cases', 'Location Level', 'City or Regency', 'Province', 'Country', 'Continent', 'Island', 'Time Zone', 'Special Status', 'Total Regencies', 'Total Cities', 'Total Districts', 'Total Urban Villages', 'Total Rural Villages', 'Area (km2)', 'Population', 'Population Density', 'Longitude', 'Latitude', 'New Cases per Million', 'Total Cases per Million', 'New Deaths per Million', 'Total Deaths per Million', 'Total Deaths per 100rb', 'Case Fatality Rate', 'Case Recovered Rate', 'Growth Factor of New Cases', 'Growth Factor of New Deaths']
# Jumlah Atribut :  38

# %% [markdown]
# #### Jumlah Atribut dengan Tipe Objek

# %%
print("Nama-nama Atribut dengan tipe data object : ", info['atribut_object'])
print("Jumlah Atribut dengan tipe data Object : ", len(info['atribut_object']))
# Out:
# Nama-nama Atribut dengan tipe data object :  ['Date', 'Location ISO Code', 'Location', 'Location Level', 'Province', 'Country', 'Continent', 'Island', 'Time Zone', 'Special Status', 'Case Fatality Rate', 'Case Recovered Rate']
# Jumlah Atribut dengan tipe data Object :  12

# %% [markdown]
# #### Jumlah Atribut dengan Tipe Data Angka

# %%
print("Nama-nama Atribut dengan tipe data Angka : ", info['atribut_number'])
print("Jumlah Atribut dengan Tipe Data Angka : ", len(info['atribut_number']))
# Out:
# Nama-nama Atribut dengan tipe data Angka :  ['New Cases', 'New Deaths', 'New Recovered', 'New Active Cases', 'Total Cases', 'Total Deaths', 'Total Recovered', 'Total Active Cases', 'City or Regency', 'Total Regencies', 'Total Cities', 'Total Districts', 'Total Urban Villages', 'Total Rural Villages', 'Area (km2)', 'Population', 'Population Density', 'Longitude', 'Latitude', 'New Cases per Million', 'Total Cases per Million', 'New Deaths per Million', 'Total Deaths per Million', 'Total Deaths per 100rb', 'Growth Factor of New Cases', 'Growth Factor of New Deaths']
# Jumlah Atribut dengan Tipe Data Angka :  26

# %% [markdown]
# #### Jumlah Atribut yang memiliki nilai null

# %%
print("Nama-nama Atribut yang memiliki nilai null : ", info['null_atribut'])
print("Jumlah Atribut yang memiliki nilai null : ", len(info['null_atribut']))
# Out:
# Nama-nama Atribut yang memiliki nilai null :  ['City or Regency', 'Province', 'Island', 'Time Zone', 'Special Status', 'Total Cities', 'Total Urban Villages', 'Total Rural Villages', 'Growth Factor of New Cases', 'Growth Factor of New Deaths']
# Jumlah Atribut yang memiliki nilai null :  10

# %% [markdown]
# #### Menampilkan Nilai Korelasi bertipe data Angka

# %%
df.corr()
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_16352\1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                              New Cases  New Deaths  New Recovered  \
# New Cases                     1.000000    0.715800       0.856939
# New Deaths                    0.715800    1.000000       0.782872
# New Recovered                 0.856939    0.782872       1.000000
# New Active Cases              0.319436   -0.102710      -0.214391
# Total Cases                   0.450040    0.330987       0.505747
# Total Deaths                  0.437586    0.346205       0.487197
# Total Recovered               0.415930    0.299173       0.472292
# Total Active Cases            0.923300    0.804404       0.938581
# City or Regency                    NaN         NaN            NaN
# ...
